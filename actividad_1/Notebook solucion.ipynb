# %%
import json
import urllib.request
import pymongo
import pprint

# %%
url_json ='https://api.bsmsa.eu/ext/api/bsm/gbfs/v2/en/station_information'
contents = urllib.request.urlopen(url_json).read()
datos_dict = json.loads(contents.decode('utf-8'))
client = pymongo.MongoClient("mongodb+srv://admin:zxcv123456@prueba-lprhj.mongodb.net/test?retryWrites=true&w=majority")
db = client.bd_actividad
dbmongo = db.actividad_1

# %%
datos_dict
# Out:
# {'last_updated': 1585456603,
#  'ttl': 30,
#  'data': {'stations': [{'station_id': 1,
#     'name': 'GRAN VIA CORTS CATALANES, 760',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 41.397952,
#     'lon': 2.180042,
#     'altitude': 21.0,
#     'address': 'GRAN VIA CORTS CATALANES, 760',
#     'post_code': '08908',
#     'capacity': 46,
#     'nearby_distance': 1000.0},
#    {'station_id': 2,
#     'name': 'C/ ROGER DE FLOR, 126',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 41.39553,
#     'lon': 2.17706,
#     'altitude': 21.0,
#     'address': 'C/ ROGER DE FLOR, 126',
#     'post_code': '08908',
#     'capacity': 27,
#     'nearby_distance': 1000.0},
#    {'station_id': 3,
#     'name': 'C/ NÀPOLS, 82',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 41.394055,
#     'lon': 2.181299,
#     'altitude': 22.0,
#     'address': 'C/ NÀPOLS, 82',
#     'post_code': '08908',
#     'capacity': 27,
# ...

# %%
datos_dict
# Out:
# {'last_updated': 1585456603,
#  'ttl': 30,
#  'data': {'stations': [{'station_id': 1,
#     'name': 'GRAN VIA CORTS CATALANES, 760',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 41.397952,
#     'lon': 2.180042,
#     'altitude': 21.0,
#     'address': 'GRAN VIA CORTS CATALANES, 760',
#     'post_code': '08908',
#     'capacity': 46,
#     'nearby_distance': 1000.0},
#    {'station_id': 2,
#     'name': 'C/ ROGER DE FLOR, 126',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 41.39553,
#     'lon': 2.17706,
#     'altitude': 21.0,
#     'address': 'C/ ROGER DE FLOR, 126',
#     'post_code': '08908',
#     'capacity': 27,
#     'nearby_distance': 1000.0},
#    {'station_id': 3,
#     'name': 'C/ NÀPOLS, 82',
#     'physical_configuration': 'ELECTRICBIKESTATION',
#     'lat': 41.394055,
#     'lon': 2.181299,
#     'altitude': 22.0,
#     'address': 'C/ NÀPOLS, 82',
#     'post_code': '08908',
#     'capacity': 27,
# ...

# %%
datos_1 = datos_dict.get('data')
datos_2 = datos_1.get("stations")
datos_2
# Out:
# [{'station_id': 1,
#   'name': 'GRAN VIA CORTS CATALANES, 760',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 41.397952,
#   'lon': 2.180042,
#   'altitude': 21.0,
#   'address': 'GRAN VIA CORTS CATALANES, 760',
#   'post_code': '08908',
#   'capacity': 46,
#   'nearby_distance': 1000.0},
#  {'station_id': 2,
#   'name': 'C/ ROGER DE FLOR, 126',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 41.39553,
#   'lon': 2.17706,
#   'altitude': 21.0,
#   'address': 'C/ ROGER DE FLOR, 126',
#   'post_code': '08908',
#   'capacity': 27,
#   'nearby_distance': 1000.0},
#  {'station_id': 3,
#   'name': 'C/ NÀPOLS, 82',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 41.394055,
#   'lon': 2.181299,
#   'altitude': 22.0,
#   'address': 'C/ NÀPOLS, 82',
#   'post_code': '08908',
#   'capacity': 27,
#   'nearby_distance': 1000.0},
#  {'station_id': 4,
#   'name': 'C/ RIBES, 13',
#   'physical_configuration': 'ELECTRICBIKESTATION',
# ...

# %%
type(datos_1)
# Out:
# dict

# %%
type(datos_2)
# Out:
# list

# %%
datos_2
# Out:
# [{'station_id': 1,
#   'name': 'GRAN VIA CORTS CATALANES, 760',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 41.397952,
#   'lon': 2.180042,
#   'altitude': 21.0,
#   'address': 'GRAN VIA CORTS CATALANES, 760',
#   'post_code': '08908',
#   'capacity': 46,
#   'nearby_distance': 1000.0},
#  {'station_id': 2,
#   'name': 'C/ ROGER DE FLOR, 126',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 41.39553,
#   'lon': 2.17706,
#   'altitude': 21.0,
#   'address': 'C/ ROGER DE FLOR, 126',
#   'post_code': '08908',
#   'capacity': 27,
#   'nearby_distance': 1000.0},
#  {'station_id': 3,
#   'name': 'C/ NÀPOLS, 82',
#   'physical_configuration': 'ELECTRICBIKESTATION',
#   'lat': 41.394055,
#   'lon': 2.181299,
#   'altitude': 22.0,
#   'address': 'C/ NÀPOLS, 82',
#   'post_code': '08908',
#   'capacity': 27,
#   'nearby_distance': 1000.0},
#  {'station_id': 4,
#   'name': 'C/ RIBES, 13',
#   'physical_configuration': 'ELECTRICBIKESTATION',
# ...

# %%
dbmongo.insert(datos_2)
# Out:
# C:\Users\alexa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# [ObjectId('5e8025e893eff7b4909f457c'),
#  ObjectId('5e8025e893eff7b4909f457d'),
#  ObjectId('5e8025e893eff7b4909f457e'),
#  ObjectId('5e8025e893eff7b4909f457f'),
#  ObjectId('5e8025e893eff7b4909f4580'),
#  ObjectId('5e8025e893eff7b4909f4581'),
#  ObjectId('5e8025e893eff7b4909f4582'),
#  ObjectId('5e8025e893eff7b4909f4583'),
#  ObjectId('5e8025e893eff7b4909f4584'),
#  ObjectId('5e8025e893eff7b4909f4585'),
#  ObjectId('5e8025e893eff7b4909f4586'),
#  ObjectId('5e8025e893eff7b4909f4587'),
#  ObjectId('5e8025e893eff7b4909f4588'),
#  ObjectId('5e8025e893eff7b4909f4589'),
#  ObjectId('5e8025e893eff7b4909f458a'),
#  ObjectId('5e8025e893eff7b4909f458b'),
#  ObjectId('5e8025e893eff7b4909f458c'),
#  ObjectId('5e8025e893eff7b4909f458d'),
#  ObjectId('5e8025e893eff7b4909f458e'),
# ...

# %%
cursor = dbmongo.find()    #Guarda el puntero y luego lo recorre con un for
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('5e8025e893eff7b4909f457c'), 'station_id': 1, 'name': 'GRAN VIA CORTS CATALANES, 760', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.397952, 'lon': 2.180042, 'altitude': 21.0, 'address': 'GRAN VIA CORTS CATALANES, 760', 'post_code': '08908', 'capacity': 46, 'nearby_distance': 1000.0}
# {'_id': ObjectId('5e8025e893eff7b4909f457d'), 'station_id': 2, 'name': 'C/ ROGER DE FLOR, 126', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.39553, 'lon': 2.17706, 'altitude': 21.0, 'address': 'C/ ROGER DE FLOR, 126', 'post_code': '08908', 'capacity': 27, 'nearby_distance': 1000.0}
# {'_id': ObjectId('5e8025e893eff7b4909f457e'), 'station_id': 3, 'name': 'C/ NÀPOLS, 82', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.394055, 'lon': 2.181299, 'altitude': 22.0, 'address': 'C/ NÀPOLS, 82', 'post_code': '08908', 'capacity': 27, 'nearby_distance': 1000.0}
# ...

# %%
for x in dbmongo.find({"capacity":30}):       #Consulta a MondoGB el atributo de capacidad de la estacion y filtra solo las estaciones con esa capacidad
    print(x)
# Out:
# {'_id': ObjectId('5e8025e893eff7b4909f458c'), 'station_id': 19, 'name': 'C/ ROSSELLÓ, 354', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.403282, 'lon': 2.170726, 'altitude': 49.0, 'address': 'C/ ROSSELLÓ, 354', 'post_code': '08908', 'capacity': 30, 'nearby_distance': 1000.0}
# {'_id': ObjectId('5e8025e893eff7b4909f4591'), 'station_id': 24, 'name': 'C/ MARINA, 199', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.400659, 'lon': 2.179111, 'altitude': 30.0, 'address': 'C/ MARINA, 199', 'post_code': '08908', 'capacity': 30, 'nearby_distance': 1000.0}
# {'_id': ObjectId('5e8025e893eff7b4909f46d7'), 'station_id': 360, 'name': 'C/ BAILÉN, 62', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.395213, 'lon': 2.172984, 'altitude': 42.0, 'address': 'C/ BAILÉN, 62', 'post_code': '08908', 'capacity': 30, 'nearby_distance': 1000.0}
# ...

# %% [markdown]
# Con este codigo, se busca los 3 (limit) mas altos (-1) de un atributo, o los 3 mas bajos (1)

# %%
for x in dbmongo.find({"capacity":{"$gt": 1}}).sort("capacity", -1).limit(3):
    print(x)
# Out:
# {'_id': ObjectId('5e8025e893eff7b4909f4587'), 'station_id': 13, 'name': 'CARRER DE LA MARINA, 25-33', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.387985, 'lon': 2.19578, 'altitude': 8.0, 'address': 'CARRER DE LA MARINA, 25-33', 'post_code': '08908', 'capacity': 54, 'nearby_distance': 1000.0}
# {'_id': ObjectId('5e8025e893eff7b4909f45a6'), 'station_id': 46, 'name': 'C/ RAMON TRIAS FARGAS, 19', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.388359, 'lon': 2.193004, 'altitude': 1.0, 'address': 'C/ RAMON TRIAS FARGAS, 19', 'post_code': '08908', 'capacity': 54, 'nearby_distance': 1000.0}
# {'_id': ObjectId('5e8025e893eff7b4909f461e'), 'station_id': 170, 'name': 'AV.LITORAL, 40 (ANNEXA A LA 169)', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.389732, 'lon': 2.199934, 'altitude': 1.0, 'address': 'AV.LITORAL, 40 (ANNEXA A LA 169)', 'post_code': '08908', 'capacity': 54, 'nearby_distance': 1000.0}

# %%
cursor = dbmongo.aggregate([{"$match" : {"name" : "C/ RIBES, 13"}}])
for x in cursor:
    print (x)
# Out:
# {'_id': ObjectId('5e8025e893eff7b4909f457f'), 'station_id': 4, 'name': 'C/ RIBES, 13', 'physical_configuration': 'ELECTRICBIKESTATION', 'lat': 41.39348, 'lon': 2.181555, 'altitude': 21.0, 'address': 'C/ RIBES, 13', 'post_code': '08908', 'capacity': 21, 'nearby_distance': 1000.0}

# %% [markdown]
# Recorrer todos los registros de la colección y realizar una media en un atributo.

# %%
cursor = dbmongo.aggregate([{"$group" : {"_id": -1, "promedio": {"$avg":"$altitude"}}}])
for x in cursor:
    print(x)
# Out:
# {'_id': -1, 'promedio': 32.322247191011236}
